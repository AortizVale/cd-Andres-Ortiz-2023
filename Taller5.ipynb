# %% [markdown]
# Taller 5
# Andrés Camilo Ortiz Vale

# %% [markdown]
# # Crear puntos aleatorios

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random

# Número de puntos que deseas generar
num_puntos = 1000000

# Genera puntos aleatorios en una cuadrícula de 1x1
puntos = [(random.uniform(0, 1), random.uniform(0, 1)) for _ in range(num_puntos)]

# Crea un DataFrame con los puntos
df1 = pd.DataFrame(puntos, columns=['X', 'Y'])

# Grafica los puntos
plt.figure(figsize=(10, 10))
# Disminuir el tamaño de los puntos
tamaño_puntos = 0.05

# Graficar los puntos con el tamaño especificado
plt.scatter(df1['X'], df1['Y'], s=tamaño_puntos)
plt.xlabel('Coordenada X', fontsize=15)
plt.ylabel('Coordenada Y', fontsize=15)
plt.title('Puntos aleatorios', fontsize=20)
plt.grid(True)

# Muestra el gráfico
plt.show()

# %%
df1
# Out:
#                X         Y
# 0       0.342879  0.202622
# 1       0.535410  0.171625
# 2       0.905981  0.664456
# 3       0.998369  0.450025
# 4       0.531464  0.732007
# ...          ...       ...
# 999995  0.493210  0.783385
# 999996  0.260363  0.499544
# 999997  0.181202  0.290882
# 999998  0.674361  0.905270
# 999999  0.048059  0.074161
#
# [1000000 rows x 2 columns]

# %% [markdown]
# # Crear puntos equisdistantes

# %%
import math

# Calcular el número de puntos en cada eje

puntos_totales = 1000000
puntos_lado=round(math.sqrt(puntos_totales))
distancia_entre_puntos=1/puntos_lado

# Crear una lista de coordenadas
coordenadas = []

# Generar puntos equidistantes en la cuadrícula de 1x1
for i in range(puntos_lado):
    for j in range(puntos_lado):
        x = i * distancia_entre_puntos
        y = j * distancia_entre_puntos
        coordenadas.append((x, y))

# Crear un DataFrame con las coordenadas
df2 = pd.DataFrame(coordenadas, columns=['X', 'Y'])

# Aumentar el tamaño de la gráfica
plt.figure(figsize=(8, 8))  # Cambia las dimensiones según tus necesidades

# Grafica los puntos
plt.figure(figsize=(10, 10))
# Disminuir el tamaño de los puntos
tamaño_puntos = 0.05

# Graficar los puntos con el tamaño especificado
plt.scatter(df2['X'], df2['Y'], s=tamaño_puntos)
plt.xlabel('Coordenada X', fontsize=15)
plt.ylabel('Coordenada Y', fontsize=15)
plt.title('Puntos equisdistantes', fontsize=20)
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %%
df2
# Out:
#             X      Y
# 0       0.000  0.000
# 1       0.000  0.001
# 2       0.000  0.002
# 3       0.000  0.003
# 4       0.000  0.004
# ...       ...    ...
# 999995  0.999  0.995
# 999996  0.999  0.996
# 999997  0.999  0.997
# 999998  0.999  0.998
# 999999  0.999  0.999
#
# [1000000 rows x 2 columns]

# %% [markdown]
# # Crear funciones necesarias

# %%
#Función que calcula la distancia entre dos puntos
def distancia(x1,y1,x2,y2):
  d=math.sqrt(((x2-x1)**2)+((y2-y1)**2))
  return d

#función que cuenta los puntos con una distancia menor o igual a 1

def distanciaMenor(puntosDF):
  x = puntosDF["X"].values.tolist()
  y = puntosDF["Y"].values.tolist()
  largo = len(puntosDF)
  parejas = 0
  for i in range(0,largo):
    x1=x[i]
    y1=y[i]
    d=distancia(x1,y1,0,0)
    if (d<=1):
        parejas=parejas+1
  return parejas

# %% [markdown]
# # Hacer estimaciones para números aleatorios

# %%
puntosMenores = distanciaMenor(df1)
print("Hay", puntosMenores, "puntos aleatorios a menos de 1 de distancia de (0,0)")
piEstimado=(puntosMenores/puntos_totales)*4
print("El valor estimado de pi para los puntos aleatorios es", piEstimado)
# Out:
# Hay 785419 puntos aleatorios a menos de 1 de distancia de (0,0)
# El valor estimado de pi para los puntos aleatorios es 3.141676

# %% [markdown]
# # Hacer estimaciones

# %%
puntosMenores = distanciaMenor(df2)
print("Hay", puntosMenores, "puntos equisdistantes a menos de 1 de distancia de (0,0)")
piEstimado=(puntosMenores/puntos_totales)*4
print("El valor estimado de pi para los puntos equisdistantes es", piEstimado)
# Out:
# Hay 786386 puntos equisdistantes a menos de 1 de distancia de (0,0)
# El valor estimado de pi para los puntos equisdistantes es 3.145544
